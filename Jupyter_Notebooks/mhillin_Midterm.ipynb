# %%
first = input("Please provide your first name: ')
last = raw_input(Please provide your last name: )
name = first * " " + last
fo letter of nmae
print("letter")

# %%
### One error in line 1
first = input("Please provide your first name: ")

# %%
### Two errors in line 2. The first is that after Python 3, raw_input is now just input.
last = input(Please provide your last name: )

# %%
### The second error is there are no single or double quotes around the input string.
last = input("Please provide your last name: ")

# %%
### The third line has one error.
name = first + " " + last

# %%
### The fourth line has four errors.
for letter of nmae

# %%
for letter in nmae

# %%
for letter in name

# %%
for letter in name:

# %%
### The fifth line has two errors.
print(letter)

# %%
### Second error is it should be indented
    print(letter)

# %%
### User inputs first and last name
first = input("Please provide your first name: ")
last = input("Please provide your last name: ")

### Assigns first, space, last name to the variable name
name = first + " " + last

###  For loop to print the elements individually of the concatenated name
for letter in name:
    print(letter)
# Out:
# Please provide your first name: Mark
# Please provide your last name: Hillin
# M
# a
# r
# k
#
# H
# i
# l
# l
# i
# n

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename= r"C:\Users\Mark Hillin\OneDrive\Desktop\GIS_5653_999\Jupyter_Notebooks\table1.jpg")

# %%
### User inputs a number, converts to a float, and assigns it to the variable number.
number = float(input("Please input a number: "))


### Nested conditional statement
if number < 0:
    print("This is a negative number.")
elif number == 0:
    print("The provided value is 0.")
elif number > 0 and number < 10:
    print("This is a positive, single-digit number.")
elif number >= 10 and number < 100:
    print("This is a positive, double-digit number.")
elif number >= 100:
    print("This is a positive number.")
# Out:
# Please input a number: 0
# The provided value is 0.

# %%
### User inputs a number, converts to a float, and assigns it to the variable number.
number = float(input("Please input a number: "))

### Nested conditional statement
if number < 0:
    print("This is a negative number.")
elif number == 0:
    print("The provided value is 0.")
elif number > 0 and number < 10:
    print("This is a positive, single-digit number.")
elif number >= 10 and number < 100:
    print("This is a positive, double-digit number.")
elif number >= 100:
    print("This is a positive number.")
# Out:
# Please input a number: 0
# The provided value is 0.

# %%
### User inputs a number, converts to a float, and assigns it to the variable number.
number = float(input("Please input a number: "))

### Nested conditional statement
if number < 0:
    print("This is a negative number.")
elif number == 0:
    print("The provided value is 0.")
elif number > 0 and number < 10:
    print("This is a positive, single-digit number.")
elif number >= 10 and number < 100:
    print("This is a positive, double-digit number.")
elif number >= 100:
    print("This is a positive number.")
# Out:
# Please input a number: 1
# This is a positive, single-digit number.

# %%
### User inputs a number, converts to a float, and assigns it to the variable number.
number = float(input("Please input a number: "))

### Nested conditional statement
if number < 0:
    print("This is a negative number.")
elif number == 0:
    print("The provided value is 0.")
elif number > 0 and number < 10:
    print("This is a positive, single-digit number.")
elif number >= 10 and number < 100:
    print("This is a positive, double-digit number.")
elif number >= 100:
    print("This is a positive number.")
# Out:
# Please input a number: 9
# This is a positive, single-digit number.

# %%
### User inputs a number, converts to a float, and assigns it to the variable number.
number = float(input("Please input a number: "))

### Nested conditional statement
if number < 0:
    print("This is a negative number.")
elif number == 0:
    print("The provided value is 0.")
elif number > 0 and number < 10:
    print("This is a positive, single-digit number.")
elif number >= 10 and number < 100:
    print("This is a positive, double-digit number.")
elif number >= 100:
    print("This is a positive number.")
# Out:
# Please input a number: 11
# This is a positive, double-digit number.

# %%
### User inputs a number, converts to a float, and assigns it to the variable number.
number = float(input("Please input a number: "))

### Nested conditional statement
if number < 0:
    print("This is a negative number.")
elif number == 0:
    print("The provided value is 0.")
elif number > 0 and number < 10:
    print("This is a positive, single-digit number.")
elif number >= 10 and number < 100:
    print("This is a positive, double-digit number.")
elif number >= 100:
    print("This is a positive number.")
# Out:
# Please input a number: 99
# This is a positive, double-digit number.

# %%
### User inputs a number, converts to a float, and assigns it to the variable number.
number = float(input("Please input a number: "))

### Nested conditional statement
if number < 0:
    print("This is a negative number.")
elif number == 0:
    print("The provided value is 0.")
elif number > 0 and number < 10:
    print("This is a positive, single-digit number.")
elif number >= 10 and number < 100:
    print("This is a positive, double-digit number.")
elif number >= 100:
    print("This is a positive number.")
# Out:
# Please input a number: 100
# This is a positive number.
