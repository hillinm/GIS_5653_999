# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(filename= r'C:\Users\Mark Hillin\OneDrive\Desktop\GIS_5653_999\Jupyter_Notebooks\Chapter6.jpg')

# %%
new_word = 3.14

if
